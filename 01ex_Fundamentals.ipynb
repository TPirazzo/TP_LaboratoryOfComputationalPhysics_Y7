# %% [markdown]
# 0\. Implement a function (whatever you want) and save it to a file (e.g. `function.py`). Import that file and use that function in this notebook.

# %%
import function as f #import the module

f.external_func() #call the functio in the module
# Out:
# Modul imported correctly

# %% [markdown]
# 1\. Write the following as a list comprehension

# %%
# 1
ans = []
for i in range(3):
    for j in range(4):
        ans.append((i, j))
print (ans)

# 2
ans = map(lambda x: x*x, filter(lambda x: x%2 == 0, range(5)))
print (list(ans))
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3)]
# [0, 4, 16]

# %%
#1
ans = print([(i,j) for i in range(3) for j in range(4)])

#2
ans = print([x*x for x in range(5) if x%2 == 0])
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3)]
# [0, 4, 16]

# %% [markdown]
# 2\. Convert the following function into a pure function with no global variables or side effects

# %%
x = 5
def f(alist):
    for i in range(x):
         alist.append(i)
    return alist

alist = [1,2,3]
ans = f(alist)
print (ans)
print (alist) # alist has been changed!
# Out:
# [1, 2, 3, 0, 1, 2, 3, 4]
# [1, 2, 3, 0, 1, 2, 3, 4]

# %%
def f_no_side(x, l):
    for i in range(x):
        l = (*l, i)
    return(l)

l = (1,2,3) #tuple is a unmutable
f = f_no_side(5, l)
print(f)
print(l)
# Out:
# (1, 2, 3, 0, 1, 2, 3, 4)
# (1, 2, 3)

# %% [markdown]
# 3\. Write a `decorator` hello that makes every wrapped function print “Hello!”, i.e. something like:
#
# ```python
# @hello
# def square(x):
#     return x*x
# ```

# %%
def hello(func):
    def wrapper(*args, **kwargs):
        print("Hello!")
        sq = func(*args, **kwargs)
        print("Computing.... \n")
        return sq
    return wrapper

@hello
def square(x):
    return x*x

@hello
def cube(x):
    return x*x*x

square(3)
cube(3)
# Out:
# Hello!
# Computing....
#
# Hello!
# Computing....
# 27

# %% [markdown]
# 4\. Write the factorial function so that it a) does and b) does not use recursion.

# %%
#using recursion
def rec_factorial(n):
    if n < 0 or n%1 != 0:
        print("n must be a natural number \n")
        return

    elif n == 0:
        return 1

    else:
        return n*rec_factorial(n-1)

print(rec_factorial(4), '\n')
# %timeit rec_factorial(20)
# Out:
# 24
#
# 5.51 μs ± 915 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
#without recursion
def no_rec_factorial(n):
    
    if n < 0 or n%1 != 0:
        print("n must be a natural number \n")
        return

    elif n == 0:
        return 1

    else:
        r = 1
        for i in range(1, n-1):
            r *= (n-i)
        return n*r

print(no_rec_factorial(4), '\n')
# %timeit no_rec_factorial(20)
# Out:
# 24
#
# 3.86 μs ± 448 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# 5\. Use HOFs (zip in particular) to compute the weight of a circle, a disk and a sphere, assuming different radii and different densities:
#
# ```python
# densities = {"Al":[0.5,1,2],"Fe":[3,4,5],"Pb": [15,20,30]}
# radii = [1,2,3]
# ```
#
# where the entries of the dictionary's values are the linear, superficial and volumetric densities of the materials respectively.
#
# In particular define a list of three lambda functions using a comprehension that computes the circumference, the area and the volume for a given radius.

# %%
import math as m

densities = {"Al":[0.5,1,2],"Fe":[3,4,5],"Pb": [15,20,30]}
radii = [1,2,3]

#create the list of lambda functions to compute circumferenze, area and volume
l_functions = [(lambda r,c=c,e=e: c*m.pi*r**e) for c,e in zip((2, 1, 4/3), (1,2,3))] 

for func in l_functions:
    for r in radii:
        for x,y,z in zip(densities['Al'], densities['Fe'],densities['Pb']):
            print(func(r)*x, x, r, '\n'  )
            print(func(r)*y, y, r, '\n'  )
            print(func(r)*z, z, r, '\n'  )
# Out:
# 3.141592653589793 0.5 1
#
# 18.84955592153876 3 1
#
# 94.24777960769379 15 1
#
# 6.283185307179586 1 1
#
# 25.132741228718345 4 1
#
# 125.66370614359172 20 1
#
# 12.566370614359172 2 1
#
# 31.41592653589793 5 1
#
# 188.49555921538757 30 1
#
# 6.283185307179586 0.5 2
#
# 37.69911184307752 3 2
#
# 188.49555921538757 15 2
#
# 12.566370614359172 1 2
#
# 50.26548245743669 4 2
#
# 251.32741228718345 20 2
#
# 25.132741228718345 2 2
#
# 62.83185307179586 5 2
#
# 376.99111843077515 30 2
#
# 9.42477796076938 0.5 3
#
# 56.548667764616276 3 3
#
# 282.7433388230814 15 3
#
# 18.84955592153876 1 3
#
# 75.39822368615503 4 3
#
# 376.99111843077515 20 3
#
# 37.69911184307752 2 3
#
# 94.24777960769379 5 3
#
# 565.4866776461628 30 3
#
# 1.5707963267948966 0.5 1
#
# 9.42477796076938 3 1
#
# 47.12388980384689 15 1
#
# 3.141592653589793 1 1
#
# 12.566370614359172 4 1
#
# 62.83185307179586 20 1
#
# 6.283185307179586 2 1
#
# 15.707963267948966 5 1
#
# 94.24777960769379 30 1
#
# 6.283185307179586 0.5 2
#
# 37.69911184307752 3 2
#
# 188.49555921538757 15 2
#
# 12.566370614359172 1 2
#
# 50.26548245743669 4 2
#
# 251.32741228718345 20 2
#
# 25.132741228718345 2 2
#
# 62.83185307179586 5 2
#
# 376.99111843077515 30 2
#
# 14.137166941154069 0.5 3
#
# 84.82300164692441 3 3
#
# 424.11500823462205 15 3
#
# 28.274333882308138 1 3
#
# 113.09733552923255 4 3
#
# 565.4866776461628 20 3
#
# 56.548667764616276 2 3
#
# 141.3716694115407 5 3
#
# 848.2300164692441 30 3
#
# 2.0943951023931953 0.5 1
#
# 12.566370614359172 3 1
#
# 62.831853071795855 15 1
#
# 4.1887902047863905 1 1
#
# 16.755160819145562 4 1
#
# 83.7758040957278 20 1
#
# 8.377580409572781 2 1
#
# 20.94395102393195 5 1
#
# 125.66370614359171 30 1
#
# 16.755160819145562 0.5 2
#
# 100.53096491487338 3 2
#
# 502.65482457436684 15 2
#
# 33.510321638291124 1 2
#
# 134.0412865531645 4 2
#
# 670.2064327658225 20 2
#
# 67.02064327658225 2 2
#
# 167.5516081914556 5 2
#
# 1005.3096491487337 30 2
#
# 56.54866776461627 0.5 3
#
# 339.29200658769764 3 3
#
# 1696.460032938488 15 3
#
# 113.09733552923254 1 3
#
# 452.38934211693015 4 3
#
# 2261.9467105846506 20 3
#
# 226.19467105846508 2 3
#
# 565.4866776461627 5 3
#
# 3392.920065876976 30 3
#
# 3.141592653589793 0.5 1
#
# 18.84955592153876 3 1
#
# 94.24777960769379 15 1
#
# 1.5707963267948966 0.5 1
#
# 9.42477796076938 3 1
#
# 47.12388980384689 15 1
#
# 2.0943951023931953 0.5 1
#
# 12.566370614359172 3 1
#
# 62.831853071795855 15 1
#
# 6.283185307179586 0.5 2
#
# 37.69911184307752 3 2
#
# 188.49555921538757 15 2
#
# 6.283185307179586 0.5 2
#
# 37.69911184307752 3 2
#
# 188.49555921538757 15 2
#
# 16.755160819145562 0.5 2
#
# 100.53096491487338 3 2
#
# 502.65482457436684 15 2
#
# 9.42477796076938 0.5 3
#
# 56.548667764616276 3 3
#
# 282.7433388230814 15 3
#
# 14.137166941154069 0.5 3
#
# 84.82300164692441 3 3
#
# 424.11500823462205 15 3
#
# 56.54866776461627 0.5 3
#
# 339.29200658769764 3 3
#
# 1696.460032938488 15 3
#
# 6.283185307179586 1 1
#
# 25.132741228718345 4 1
#
# 125.66370614359172 20 1
#
# 3.141592653589793 1 1
#
# 12.566370614359172 4 1
#
# 62.83185307179586 20 1
#
# 4.1887902047863905 1 1
#
# 16.755160819145562 4 1
#
# 83.7758040957278 20 1
#
# 12.566370614359172 1 2
#
# 50.26548245743669 4 2
#
# 251.32741228718345 20 2
#
# 12.566370614359172 1 2
#
# 50.26548245743669 4 2
#
# 251.32741228718345 20 2
#
# 33.510321638291124 1 2
#
# 134.0412865531645 4 2
#
# 670.2064327658225 20 2
#
# 18.84955592153876 1 3
#
# 75.39822368615503 4 3
#
# 376.99111843077515 20 3
#
# 28.274333882308138 1 3
#
# 113.09733552923255 4 3
#
# 565.4866776461628 20 3
#
# 113.09733552923254 1 3
#
# 452.38934211693015 4 3
#
# 2261.9467105846506 20 3
#
# 12.566370614359172 2 1
#
# 31.41592653589793 5 1
#
# 188.49555921538757 30 1
#
# 6.283185307179586 2 1
#
# 15.707963267948966 5 1
#
# 94.24777960769379 30 1
#
# 8.377580409572781 2 1
#
# 20.94395102393195 5 1
#
# 125.66370614359171 30 1
#
# 25.132741228718345 2 2
#
# 62.83185307179586 5 2
#
# 376.99111843077515 30 2
#
# 25.132741228718345 2 2
#
# 62.83185307179586 5 2
#
# 376.99111843077515 30 2
#
# 67.02064327658225 2 2
#
# 167.5516081914556 5 2
#
# 1005.3096491487337 30 2
#
# 37.69911184307752 2 3
#
# 94.24777960769379 5 3
#
# 565.4866776461628 30 3
#
# 56.548667764616276 2 3
#
# 141.3716694115407 5 3
#
# 848.2300164692441 30 3
#
# 226.19467105846508 2 3
#
# 565.4866776461627 5 3
#
# 3392.920065876976 30 3

# %% [markdown]
# 6\. Edit the class defintion to add an instance attribute of is_hungry = True to the Dog class. Then add a method called eat() which changes the value of is_hungry to False when called. Figure out the best way to feed each dog and then output “My dogs are hungry.” if all are hungry or “My dogs are not hungry.” if all are not hungry. The final output should look like this:
#
# `I have 3 dogs.
# Tom is 6.
# Fletcher is 7.
# Larry is 9.
# And they're all mammals, of course.
# My dogs are not hungry.
# `
#
# ```python
# # Parent class
# class Dog:
#
#     # Class attribute
#     species = 'mammal'
#
#     # Initializer / Instance attributes
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     # instance method
#     def description(self):
#         return "{} is {} years old".format(self.name, self.age)
#
#     # instance method
#     def speak(self, sound):
#         return "{} says {}".format(self.name, sound)
#
# # Child class (inherits from Dog class)
# class RussellTerrier(Dog):
#     def run(self, speed):
#         return "{} runs {}".format(self.name, speed)
#
# # Child class (inherits from Dog class)
# class Bulldog(Dog):
#     def run(self, speed):
#         return "{} runs {}".format(self.name, speed)
# ```
